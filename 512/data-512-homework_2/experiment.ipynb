# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Data Acquisition
#
# The data required to bootstrap the analysis and acquire article quality was given in CSV form by the class instructor. URLs are evident in the code below. I do not know the lifespan of these URLs or how how they were gathered.
#
# Some notable countries are inexplicably missing from the politician data, e.g. United States and United Kingdom, as well as a slew of very low population countries. The full list is presented in in the analysis section of this document.
#
# Intermediate datasets are stored for each step: acquisition, pre-processing, and analysis.

# %%
# Get the dinosaur CSV
import utils

import pandas as pd
import json
from unidecode import unidecode

def gen_file_name(id, extension='json'): # TODO move to utils
    t = utils.ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE
    return "dino_monthy_" + id + "_" + t['start'] + t['end'] + "." + extension

# Get politicians_by_country.SEPT.2022.csv
utils.download_csv(
    'https://docs.google.com/spreadsheets/u/0/d/1Y4vSTYENgNE5KltqKZqnRQQBQZN5c8uKbSM4QTt8QGg/export?format=csv', 
    'data/politicans_by_country_raw.csv')

# Get population_by_country_2022.csv
utils.download_csv(
    'https://docs.google.com/spreadsheets/u/0/d/1POuZDfA1sRooBq9e1RNukxyzHZZ-nQ2r6H5NcXhsMPU/export?format=csv', 
    'data/population_by_country_raw.csv')

# %% [markdown]
# ### Data Processing
#
# Pre-analysis processing includes remapping column names, acquiring ORES ratings for each article, and finally combining the population and politician data sets. The end product of this process is `data/combined.csv`. Some ad hoc "pre-processing" steps are performed in the analysis section as well; they are explicitly stated.
#
# For each article, we acquire the latest revision id. (Note that Wikipedia articles are continuously revised, so subsequent executions of this notbook will likely yeild different results). The ORES system consumes this revision id and returns a rating for the wikipedia rating for the article.
#
# Finally, we combine the popluation and politician datasets by country. However, not all countries had an associated politician. A list of these countries is provided below.

# %%
df_pop = pd.read_csv('data/population_by_country_raw.csv')
df_pol = pd.read_csv('data/politicans_by_country_raw.csv')

current_region = ""

def get_region(row):
    global current_region
    c = row['Geography']
    if c == c.upper(): # REGION
        current_region = c 
    return current_region


# Clean population dataset
df_pop['region'] = df_pop.apply(lambda r: get_region(r), axis=1)

df_pop['country'] = df_pop['Geography'] # TODO: just do a rename
df_pop['population'] = df_pop['Population (millions)']

df_pop = df_pop[df_pop['country'] != df_pop['country'].str.upper()]

df_pop.to_csv('data/population_by_country.csv')

# %%
# Get all the latest revision ID for each artile
json_accum = []

def get_latest_revision_id(row):
    j = utils.get_article_revid(row['name'])
    #print(row)
    #print(j)
    try:
        return list(j['query']['pages'].values())[0]['lastrevid']
    except KeyError:
        return None

df_pol1 = df_pol.copy()

df_pol1['revid'] = df_pol.apply(get_latest_revision_id, axis=1)

df_pol1.to_csv('data/politicans_by_country_revid.csv')

# %%
df_pol1 = pd.read_csv('data/politicans_by_country_revid.csv')

# %%
# Here, we acquire a ORES rating for each article 

def get_article_rating(row):
    id = str(int(row['revid']))
    
    j = utils.get_article_rating(id)
    print(row)
    print(json.dumps(j, indent=2))
    try:
        rating = j['enwiki']['scores'][id]['wp10']['score']['prediction']
        print("RATING: " + rating)
        return rating
    except KeyError: # TODO: remove this
        print("RAITING: None")
        return None

df_pol2 = df_pol1[df_pol1['revid'].isna() == False]

df_pol2['rating'] = df_pol2.apply(get_article_rating, axis=1)

df_pol2.to_csv('data/politicans_by_country_rating.csv')
# Out:
# Unnamed: 0                                                0
# name                                        Shahjahan Noori
# url           https://en.wikipedia.org/wiki/Shahjahan_Noori
# country                                         Afghanistan
# revid                                          1099689043.0
# Name: 0, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1099689043": {
#         "wp10": {
#           "score": {
#             "prediction": "GA",
#             "probability": {
#               "B": 0.15912710013204634,
#               "C": 0.3317754589473183,
#               "FA": 0.029544640342677096,
#               "GA": 0.43829652594886387,
#               "Start": 0.034888134844429625,
#               "Stub": 0.006368139784664634
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: GA
# Unnamed: 0                                                    1
# name                                      Abdul Ghafar Lakanwal
# url           https://en.wikipedia.org/wiki/Abdul_Ghafar_Lak...
# country                                             Afghanistan
# revid                                               943562276.0
# Name: 1, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "943562276": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.07072934643314852,
#               "C": 0.1558800154966825,
#               "FA": 0.004030673144978522,
#               "GA": 0.024921780108641316,
#               "Start": 0.6869179863051769,
#               "Stub": 0.05752019851137227
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                               2
# name                                        Majah Ha Adrif
# url           https://en.wikipedia.org/wiki/Majah_Ha_Adrif
# country                                        Afghanistan
# revid                                          852404094.0
# Name: 2, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "852404094": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.10924947902728685,
#               "C": 0.25115512752704433,
#               "FA": 0.006312965598375105,
#               "GA": 0.017314064629803255,
#               "Start": 0.5549263160838714,
#               "Stub": 0.061042047133619
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                                  3
# name                                        Haroon al-Afghani
# url           https://en.wikipedia.org/wiki/Haroon_al-Afghani
# country                                           Afghanistan
# revid                                            1095102390.0
# Name: 3, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1095102390": {
#         "wp10": {
#           "score": {
#             "prediction": "B",
#             "probability": {
#               "B": 0.4372459668390514,
#               "C": 0.3493904536064202,
#               "FA": 0.07082287019416104,
#               "GA": 0.0843623043187118,
#               "Start": 0.053023133532044874,
#               "Stub": 0.005155271509610824
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: B
# Unnamed: 0                                            4
# name                                        Tayyab Agha
# url           https://en.wikipedia.org/wiki/Tayyab_Agha
# country                                     Afghanistan
# revid                                      1104998382.0
# Name: 4, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1104998382": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.08162876173098238,
#               "C": 0.2463670066070844,
#               "FA": 0.005566898114337135,
#               "GA": 0.018451015385075382,
#               "Start": 0.597924570506648,
#               "Stub": 0.050061747655872554
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                                 5
# name                                        Ahmadullah Wasiq
# url           https://en.wikipedia.org/wiki/Ahmadullah_Wasiq
# country                                          Afghanistan
# revid                                           1109361754.0
# Name: 5, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1109361754": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.05364884405948932,
#               "C": 0.13846302416389905,
#               "FA": 0.005397085890032411,
#               "GA": 0.013036657139335977,
#               "Start": 0.5950688917536112,
#               "Stub": 0.19438549699363203
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                               6
# name                                        Aziza Ahmadyar
# url           https://en.wikipedia.org/wiki/Aziza_Ahmadyar
# country                                        Afghanistan
# revid                                         1087211008.0
# Name: 6, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1087211008": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.044605184972074316,
#               "C": 0.09432758129668908,
#               "FA": 0.004567933145289634,
#               "GA": 0.018574221809477067,
#               "Start": 0.6878780046062692,
#               "Stub": 0.15004707417020058
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                                  7
# name                                        Muqadasa Ahmadzai
# url           https://en.wikipedia.org/wiki/Muqadasa_Ahmadzai
# country                                           Afghanistan
# revid                                            1082489593.0
# Name: 7, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1082489593": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.048069566834345025,
#               "C": 0.13999030166768367,
#               "FA": 0.004291631789577798,
#               "GA": 0.0161539533863841,
#               "Start": 0.7370816285828834,
#               "Stub": 0.05441291773912604
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                                    8
# name                                   Mohammad Sarwar Ahmedzai
# url           https://en.wikipedia.org/wiki/Mohammad_Sarwar_...
# country                                             Afghanistan
# revid                                              1038918070.0
# Name: 8, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1038918070": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.06715520305413866,
#               "C": 0.3042686926269415,
#               "FA": 0.0061228301001578925,
#               "GA": 0.015611183313679508,
#               "Start": 0.5748880583707174,
#               "Stub": 0.03195403253436519
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                                    9
# name                                   Amir Muhammad Akhundzada
# url           https://en.wikipedia.org/wiki/Amir_Muhammad_Ak...
# country                                             Afghanistan
# revid                                              1069322182.0
# Name: 9, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1069322182": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.11383136937420064,
#               "C": 0.1013761959624893,
#               "FA": 0.004623660071546491,
#               "GA": 0.01962828296675684,
#               "Start": 0.5416807025717034,
#               "Stub": 0.2188597890533034
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                                   10
# name                                 Nasrullah Baryalai Arsalai
# url           https://en.wikipedia.org/wiki/Nasrullah_Baryal...
# country                                             Afghanistan
# revid                                              1095526840.0
# Name: 10, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1095526840": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.19734667968709535,
#               "C": 0.37197094577036344,
#               "FA": 0.006471438362836147,
#               "GA": 0.03808059423678358,
#               "Start": 0.3783020155149336,
#               "Stub": 0.007828326427987732
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                                  11
# name                                        Mohammad Asim Asim
# url           https://en.wikipedia.org/wiki/Mohammad_Asim_Asim
# country                                            Afghanistan
# revid                                             1013838830.0
# Name: 11, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1013838830": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.017602679257176707,
#               "C": 0.03741549736464354,
#               "FA": 0.00349656390489947,
#               "GA": 0.008839274681301947,
#               "Start": 0.24961539813724162,
#               "Stub": 0.6830305866547366
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                                 12
# name                                        Atiqullah Atifmal
# url           https://en.wikipedia.org/wiki/Atiqullah_Atifmal
# country                                           Afghanistan
# revid                                            1112407669.0
# Name: 12, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1112407669": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.052599828816476346,
#               "C": 0.3905512262305917,
#               "FA": 0.003522292240656525,
#               "GA": 0.0075517705703385535,
#               "Start": 0.5328802022119873,
#               "Stub": 0.012894679929949561
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                                  13
# name                                        Abdul Rahim Ayoubi
# url           https://en.wikipedia.org/wiki/Abdul_Rahim_Ayoubi
# country                                            Afghanistan
# revid                                             1108886061.0
# Name: 13, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1108886061": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.15209527292691122,
#               "C": 0.25361702070103137,
#               "FA": 0.007374276119039207,
#               "GA": 0.07462420667386684,
#               "Start": 0.42878844745562084,
#               "Stub": 0.08350077612353046
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                                  14
# name                                        Alhaj Mutalib Baig
# url           https://en.wikipedia.org/wiki/Alhaj_Mutalib_Baig
# country                                            Afghanistan
# revid                                             1111494041.0
# Name: 14, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1111494041": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.025020022134086828,
#               "C": 0.062193226577387406,
#               "FA": 0.003944770566452563,
#               "GA": 0.009795659237699754,
#               "Start": 0.5217026949277193,
#               "Stub": 0.37734362655665415
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                             15
# name                                        Ismael Balkhi
# url           https://en.wikipedia.org/wiki/Ismael_Balkhi
# country                                       Afghanistan
# revid                                        1112534409.0
# Name: 15, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1112534409": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.08977139548647899,
#               "C": 0.36017880663120344,
#               "FA": 0.00468594152535694,
#               "GA": 0.008529506535149334,
#               "Start": 0.5274204854632768,
#               "Stub": 0.009413864358534635
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                                   16
# name                                      Abdul Baqi Turkistani
# url           https://en.wikipedia.org/wiki/Abdul_Baqi_Turki...
# country                                             Afghanistan
# revid                                               889226470.0
# Name: 16, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "889226470": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.007091197985976529,
#               "C": 0.00988694309793145,
#               "FA": 0.0013671113336597798,
#               "GA": 0.0032571737595683825,
#               "Start": 0.03951744171675294,
#               "Stub": 0.9388801321061109
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                                   17
# name                                     Mohammad Ghous Bashiri
# url           https://en.wikipedia.org/wiki/Mohammad_Ghous_B...
# country                                             Afghanistan
# revid                                              1102150221.0
# Name: 17, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1102150221": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.02497519110615972,
#               "C": 0.05388378307581009,
#               "FA": 0.003661078705282161,
#               "GA": 0.0066257232862512935,
#               "Start": 0.5264060498853931,
#               "Stub": 0.38444817394110364
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                          18
# name                                        Abas Basir
# url           https://en.wikipedia.org/wiki/Abas_Basir
# country                                    Afghanistan
# revid                                     1098419766.0
# Name: 18, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1098419766": {
#         "wp10": {
#           "score": {
#             "prediction": "C",
#             "probability": {
#               "B": 0.2245100371244012,
#               "C": 0.6020965243990151,
#               "FA": 0.014734681892244757,
#               "GA": 0.0930831160075247,
#               "Start": 0.058495022047083074,
#               "Stub": 0.007080618529731163
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: C
# Unnamed: 0                                       19
# name                                        Jan Baz
# url           https://en.wikipedia.org/wiki/Jan_Baz
# country                                 Afghanistan
# revid                                   997027082.0
# Name: 19, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "997027082": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.011765958426758722,
#               "C": 0.01755985885311732,
#               "FA": 0.002203477534401091,
#               "GA": 0.004956038156685699,
#               "Start": 0.17164008491418992,
#               "Stub": 0.7918745821148473
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                            20
# name                                        Ahmad Behzad
# url           https://en.wikipedia.org/wiki/Ahmad_Behzad
# country                                      Afghanistan
# revid                                       1103948295.0
# Name: 20, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1103948295": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.09114342748045039,
#               "C": 0.19776932056705063,
#               "FA": 0.006143687020125772,
#               "GA": 0.01537314832337927,
#               "Start": 0.5882497261937162,
#               "Stub": 0.10132069041527773
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                                  21
# name                                        Bashir Ahmad Bezan
# url           https://en.wikipedia.org/wiki/Bashir_Ahmad_Bezan
# country                                            Afghanistan
# revid                                             1060707209.0
# Name: 21, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1060707209": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.0470610946544993,
#               "C": 0.14646632331385365,
#               "FA": 0.005441494435119203,
#               "GA": 0.013906414973676897,
#               "Start": 0.4182371855463139,
#               "Stub": 0.36888748707653707
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                               22
# name                                        Rafiullah Bidar
# url           https://en.wikipedia.org/wiki/Rafiullah_Bidar
# country                                         Afghanistan
# revid                                           977208323.0
# Name: 22, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "977208323": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.024076824501671947,
#               "C": 0.06839870489691124,
#               "FA": 0.003598792127999617,
#               "GA": 0.009099879675071202,
#               "Start": 0.21438360708932322,
#               "Stub": 0.6804421917090226
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                                   23
# name                                    Mohammad Siddiq Chakari
# url           https://en.wikipedia.org/wiki/Mohammad_Siddiq_...
# country                                             Afghanistan
# revid                                              1105913099.0
# Name: 23, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1105913099": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.011454169519147418,
#               "C": 0.0139893338946075,
#               "FA": 0.00220035417863789,
#               "GA": 0.004299032080815893,
#               "Start": 0.18054768585175962,
#               "Stub": 0.7875094244750318
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                                   24
# name                                        Cheragh Ali Cheragh
# url           https://en.wikipedia.org/wiki/Cheragh_Ali_Cheragh
# country                                             Afghanistan
# revid                                              1087211968.0
# Name: 24, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1087211968": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.08318916534908218,
#               "C": 0.23560826499636178,
#               "FA": 0.0042853270689398315,
#               "GA": 0.009704920373533238,
#               "Start": 0.648872824041925,
#               "Stub": 0.018339498170158085
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                                   25
# name                                        Nasir Ahmad Durrani
# url           https://en.wikipedia.org/wiki/Nasir_Ahmad_Durrani
# country                                             Afghanistan
# revid                                               988838315.0
# Name: 25, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "988838315": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.013680416148341605,
#               "C": 0.027369644837949424,
#               "FA": 0.0023482868624900956,
#               "GA": 0.005427211655943344,
#               "Start": 0.1592570297263391,
#               "Stub": 0.7919174107689364
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                           26
# name                                        Elay Ershad
# url           https://en.wikipedia.org/wiki/Elay_Ershad
# country                                     Afghanistan
# revid                                      1102489654.0
# Name: 26, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1102489654": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.026284033168405142,
#               "C": 0.05767890647111033,
#               "FA": 0.004345208231514952,
#               "GA": 0.011488878192535398,
#               "Start": 0.44103156315999553,
#               "Stub": 0.4591714107764387
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                                   27
# name                                Muhammad Hashim Esmatullahi
# url           https://en.wikipedia.org/wiki/Muhammad_Hashim_...
# country                                             Afghanistan
# revid                                               949986748.0
# Name: 27, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "949986748": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.011136786057693792,
#               "C": 0.02098173309065742,
#               "FA": 0.0023271006469762615,
#               "GA": 0.004812237279538521,
#               "Start": 0.27634268552283836,
#               "Stub": 0.6843994574022956
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                                   28
# name                                      Ezatullah (Nangarhar)
# url           https://en.wikipedia.org/wiki/Ezatullah_(Nanga...
# country                                             Afghanistan
# revid                                               947885788.0
# Name: 28, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "947885788": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.007302606159654671,
#               "C": 0.010760450936070465,
#               "FA": 0.0014514518858496632,
#               "GA": 0.0033846393148918197,
#               "Start": 0.03652258621329995,
#               "Stub": 0.9405782654902333
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                           29
# name                                        Aimal Faizi
# url           https://en.wikipedia.org/wiki/Aimal_Faizi
# country                                     Afghanistan
# revid                                      1033383351.0
# Name: 29, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1033383351": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.021928761381999028,
#               "C": 0.04943781016566443,
#               "FA": 0.0035527880394051643,
#               "GA": 0.009155740156955146,
#               "Start": 0.31749875536115607,
#               "Stub": 0.5984261448948202
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                                   30
# name                                      Mohammad Nasim Faqiri
# url           https://en.wikipedia.org/wiki/Mohammad_Nasim_F...
# country                                             Afghanistan
# revid                                              1098051193.0
# Name: 30, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1098051193": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.07274004351793387,
#               "C": 0.24097459180663544,
#               "FA": 0.004756060631361912,
#               "GA": 0.028482349692697695,
#               "Start": 0.6278138199384331,
#               "Stub": 0.025233134412937983
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                                   31
# name                                      Mohammad Nazar Faqiri
# url           https://en.wikipedia.org/wiki/Mohammad_Nazar_F...
# country                                             Afghanistan
# revid                                              1095525798.0
# Name: 31, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1095525798": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.02244015528818583,
#               "C": 0.06833349757980628,
#               "FA": 0.003451559168830831,
#               "GA": 0.008580587554620711,
#               "Start": 0.3708151734522843,
#               "Stub": 0.526379026956272
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                             32
# name                                        Sharif Ghalib
# url           https://en.wikipedia.org/wiki/Sharif_Ghalib
# country                                       Afghanistan
# revid                                        1041460606.0
# Name: 32, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1041460606": {
#         "wp10": {
#           "score": {
#             "prediction": "B",
#             "probability": {
#               "B": 0.36875405294004204,
#               "C": 0.2697246315560289,
#               "FA": 0.006962952404934864,
#               "GA": 0.010334107207918964,
#               "Start": 0.32530612491049166,
#               "Stub": 0.01891813098058343
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: B
# Unnamed: 0                                                   33
# name                                     Hashmat Ghani Ahmadzai
# url           https://en.wikipedia.org/wiki/Hashmat_Ghani_Ah...
# country                                             Afghanistan
# revid                                              1112933356.0
# Name: 33, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1112933356": {
#         "wp10": {
#           "score": {
#             "prediction": "C",
#             "probability": {
#               "B": 0.11797813737140195,
#               "C": 0.48134927448949916,
#               "FA": 0.004818167497532554,
#               "GA": 0.016633359867478097,
#               "Start": 0.37507611208242175,
#               "Stub": 0.004144948691666569
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: C
# Unnamed: 0                                                 34
# name                                        Abdul Ghani Ghani
# url           https://en.wikipedia.org/wiki/Abdul_Ghani_Ghani
# country                                           Afghanistan
# revid                                            1072441893.0
# Name: 34, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1072441893": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.011613239354594185,
#               "C": 0.017732890276177547,
#               "FA": 0.002395982810315852,
#               "GA": 0.005235291485904552,
#               "Start": 0.06011458154402555,
#               "Stub": 0.9029080145289822
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                            35
# name                                        Ashraf Ghani
# url           https://en.wikipedia.org/wiki/Ashraf_Ghani
# country                                      Afghanistan
# revid                                       1113195582.0
# Name: 35, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1113195582": {
#         "wp10": {
#           "score": {
#             "prediction": "B",
#             "probability": {
#               "B": 0.3234652401249112,
#               "C": 0.31315741114166834,
#               "FA": 0.07594826186474625,
#               "GA": 0.26968886881274645,
#               "Start": 0.012890432128935862,
#               "Stub": 0.00484978592699196
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: B
# Unnamed: 0                                                 36
# name                                        Abdul Samad Ghaus
# url           https://en.wikipedia.org/wiki/Abdul_Samad_Ghaus
# country                                           Afghanistan
# revid                                            1072271854.0
# Name: 36, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1072271854": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.024740272056569763,
#               "C": 0.05313962773091897,
#               "FA": 0.005077029135906344,
#               "GA": 0.010332333665935655,
#               "Start": 0.3371757025617788,
#               "Stub": 0.5695350348488905
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                            37
# name                                        Ghulam Ghaus
# url           https://en.wikipedia.org/wiki/Ghulam_Ghaus
# country                                      Afghanistan
# revid                                       1115758710.0
# Name: 37, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1115758710": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.009861490670611785,
#               "C": 0.013890198731287776,
#               "FA": 0.002098329905703277,
#               "GA": 0.004900827209234978,
#               "Start": 0.08266670443181065,
#               "Stub": 0.8865824490513515
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                                   38
# name                                     Ghulam Muhammad Ghobar
# url           https://en.wikipedia.org/wiki/Ghulam_Muhammad_...
# country                                             Afghanistan
# revid                                              1108886395.0
# Name: 38, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1108886395": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.018246946722087654,
#               "C": 0.038069952192441595,
#               "FA": 0.003402613599928664,
#               "GA": 0.008484012768388569,
#               "Start": 0.20605510418156225,
#               "Stub": 0.7257413705355913
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                                   39
# name                             Mohammad Gul (Helmand Council)
# url           https://en.wikipedia.org/wiki/Mohammad_Gul_(He...
# country                                             Afghanistan
# revid                                              1092523687.0
# Name: 39, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1092523687": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.0053810224707807,
#               "C": 0.00909961301650944,
#               "FA": 0.0010272094497276914,
#               "GA": 0.0024076844308545333,
#               "Start": 0.021335113838674303,
#               "Stub": 0.9607493567934534
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                                   40
# name                                       Ghulam Haider Hamidi
# url           https://en.wikipedia.org/wiki/Ghulam_Haider_Ha...
# country                                             Afghanistan
# revid                                              1095018556.0
# Name: 40, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1095018556": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.07593128819875541,
#               "C": 0.1951462786292388,
#               "FA": 0.007025999282171129,
#               "GA": 0.03666239232568941,
#               "Start": 0.5845598109545489,
#               "Stub": 0.10067423060959646
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                              41
# name                                        Rangina Hamidi
# url           https://en.wikipedia.org/wiki/Rangina_Hamidi
# country                                        Afghanistan
# revid                                         1104280812.0
# Name: 41, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1104280812": {
#         "wp10": {
#           "score": {
#             "prediction": "C",
#             "probability": {
#               "B": 0.13366547010754778,
#               "C": 0.6134266365851692,
#               "FA": 0.006843055871323805,
#               "GA": 0.12092032898614354,
#               "Start": 0.11727793130591017,
#               "Stub": 0.007866577143905418
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: C
# Unnamed: 0                                                  42
# name                                        Abdul Malik Hamwar
# url           https://en.wikipedia.org/wiki/Abdul_Malik_Hamwar
# country                                            Afghanistan
# revid                                             1100874645.0
# Name: 42, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1100874645": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.01865897207891458,
#               "C": 0.030640352167956266,
#               "FA": 0.0032063641137558534,
#               "GA": 0.007945035017416488,
#               "Start": 0.33985881504912707,
#               "Stub": 0.5996904615728297
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                                   43
# name                                        Sayed Zafar Hashemi
# url           https://en.wikipedia.org/wiki/Sayed_Zafar_Hashemi
# country                                             Afghanistan
# revid                                              1112804808.0
# Name: 43, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1112804808": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.022492874779686145,
#               "C": 0.048314147536139135,
#               "FA": 0.004360716469687504,
#               "GA": 0.009417557993881023,
#               "Start": 0.46294688850682175,
#               "Stub": 0.4524678147137845
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                               44
# name                                        Qutbuddin Hilal
# url           https://en.wikipedia.org/wiki/Qutbuddin_Hilal
# country                                         Afghanistan
# revid                                          1104423275.0
# Name: 44, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1104423275": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.03896455085311486,
#               "C": 0.15013794038468628,
#               "FA": 0.005913909350182252,
#               "GA": 0.011866132849394065,
#               "Start": 0.7135329084553785,
#               "Stub": 0.07958455810724388
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                               45
# name                                        Shahnaz Himmeti
# url           https://en.wikipedia.org/wiki/Shahnaz_Himmeti
# country                                         Afghanistan
# revid                                           909966254.0
# Name: 45, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "909966254": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.006765824990575766,
#               "C": 0.010559833632382675,
#               "FA": 0.0014367613424374176,
#               "GA": 0.003173284932139863,
#               "Start": 0.018544336003735114,
#               "Stub": 0.9595199590987292
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                                   46
# name                                     Anarkali Kaur Honaryar
# url           https://en.wikipedia.org/wiki/Anarkali_Kaur_Ho...
# country                                             Afghanistan
# revid                                              1069574154.0
# Name: 46, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1069574154": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.047573235598118074,
#               "C": 0.13037250522846328,
#               "FA": 0.004053602052940694,
#               "GA": 0.019953777616894864,
#               "Start": 0.740007953636549,
#               "Stub": 0.05803892586703407
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                               47
# name                                        Mahboba Hoqomal
# url           https://en.wikipedia.org/wiki/Mahboba_Hoqomal
# country                                         Afghanistan
# revid                                          1092518990.0
# Name: 47, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1092518990": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.014917292018875627,
#               "C": 0.033696969489130126,
#               "FA": 0.0021422675201388237,
#               "GA": 0.00542497344278855,
#               "Start": 0.11122641454438043,
#               "Stub": 0.8325920829846865
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                          48
# name                                        Musa Hotak
# url           https://en.wikipedia.org/wiki/Musa_Hotak
# country                                    Afghanistan
# revid                                     1094201417.0
# Name: 48, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1094201417": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.021130961924330772,
#               "C": 0.046568331783923354,
#               "FA": 0.0033228784290484743,
#               "GA": 0.006116018923061368,
#               "Start": 0.6026223109319133,
#               "Stub": 0.3202394980077228
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                                   49
# name                                      Mirza Muhammad Ismail
# url           https://en.wikipedia.org/wiki/Mirza_Muhammad_I...
# country                                             Afghanistan
# revid                                              1073524466.0
# Name: 49, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1073524466": {
#         "wp10": {
#           "score": {
#             "prediction": "C",
#             "probability": {
#               "B": 0.25187471772836106,
#               "C": 0.6157047201428301,
#               "FA": 0.007527813783083513,
#               "GA": 0.03989059266521576,
#               "Start": 0.07693496115437945,
#               "Stub": 0.008067194526130065
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: C
# Unnamed: 0                                           50
# name                                        Sayed Jalal
# url           https://en.wikipedia.org/wiki/Sayed_Jalal
# country                                     Afghanistan
# revid                                      1078580238.0
# Name: 50, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1078580238": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.031991080047799735,
#               "C": 0.07324543798202238,
#               "FA": 0.004241867122401291,
#               "GA": 0.007549299652294376,
#               "Start": 0.7253860347686687,
#               "Stub": 0.15758628042681355
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                                51
# name                                        Said Tayeb Jawad
# url           https://en.wikipedia.org/wiki/Said_Tayeb_Jawad
# country                                          Afghanistan
# revid                                           1093621927.0
# Name: 51, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1093621927": {
#         "wp10": {
#           "score": {
#             "prediction": "C",
#             "probability": {
#               "B": 0.24519228162289652,
#               "C": 0.3710872402394372,
#               "FA": 0.0872946893267749,
#               "GA": 0.2715360944651402,
#               "Start": 0.018887845073067896,
#               "Stub": 0.0060018492726833
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: C
# Unnamed: 0                                               52
# name                                        Faizullah Kakar
# url           https://en.wikipedia.org/wiki/Faizullah_Kakar
# country                                         Afghanistan
# revid                                          1108932917.0
# Name: 52, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1108932917": {
#         "wp10": {
#           "score": {
#             "prediction": "C",
#             "probability": {
#               "B": 0.20949451629138086,
#               "C": 0.5701450474477965,
#               "FA": 0.017544807734613477,
#               "GA": 0.05214223164637343,
#               "Start": 0.14253923059247572,
#               "Stub": 0.008134166287360143
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: C
# Unnamed: 0                                          53
# name                                        Amin Karim
# url           https://en.wikipedia.org/wiki/Amin_Karim
# country                                    Afghanistan
# revid                                     1106333491.0
# Name: 53, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1106333491": {
#         "wp10": {
#           "score": {
#             "prediction": "C",
#             "probability": {
#               "B": 0.17208816785895575,
#               "C": 0.45960078832184154,
#               "FA": 0.004886518846602261,
#               "GA": 0.03174980718153017,
#               "Start": 0.3261788155987949,
#               "Stub": 0.00549590219227541
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: C
# Unnamed: 0                                                 54
# name                                        Sayed Jalal Karim
# url           https://en.wikipedia.org/wiki/Sayed_Jalal_Karim
# country                                           Afghanistan
# revid                                            1060701067.0
# Name: 54, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1060701067": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.09732414377592083,
#               "C": 0.2444745057613898,
# ...
#               "C": 0.010367075183372732,
#               "FA": 0.0014245884399038376,
#               "GA": 0.0033429657112847276,
#               "Start": 0.029131587354518356,
#               "Stub": 0.9487290323460308
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                         3059
# name                                        Mohamad Isa
# url           https://en.wikipedia.org/wiki/Mohamad_Isa
# country                                       Indonesia
# revid                                      1097052642.0
# Name: 3059, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1097052642": {
#         "wp10": {
#           "score": {
#             "prediction": "GA",
#             "probability": {
#               "B": 0.15086606850522136,
#               "C": 0.1612576272598798,
#               "FA": 0.11687291106460969,
#               "GA": 0.5422210719262855,
#               "Start": 0.023221550744853135,
#               "Stub": 0.005560770499150471
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: GA
# Unnamed: 0                                          3060
# name                                        Herman Monim
# url           https://en.wikipedia.org/wiki/Herman_Monim
# country                                        Indonesia
# revid                                       1066805579.0
# Name: 3060, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1066805579": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.07257078699065866,
#               "C": 0.19495640270664535,
#               "FA": 0.005980402731300886,
#               "GA": 0.025433401312472157,
#               "Start": 0.6347948204540177,
#               "Stub": 0.06626418580490524
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                             3061
# name                                        Burhan Muhammad
# url           https://en.wikipedia.org/wiki/Burhan_Muhammad
# country                                           Indonesia
# revid                                          1063404014.0
# Name: 3061, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1063404014": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.00778966847946632,
#               "C": 0.010103194091316343,
#               "FA": 0.0014946261728726045,
#               "GA": 0.00285979435519169,
#               "Start": 0.039309683628887454,
#               "Stub": 0.9384430332722654
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                             3062
# name                                        Farouk Muhammad
# url           https://en.wikipedia.org/wiki/Farouk_Muhammad
# country                                           Indonesia
# revid                                          1098835847.0
# Name: 3062, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1098835847": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.007753093452465578,
#               "C": 0.012110575907290812,
#               "FA": 0.001532191058894097,
#               "GA": 0.0037688680197730208,
#               "Start": 0.024881878789969558,
#               "Stub": 0.949953392771607
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                              3063
# name                                        Ali Masykur Musa
# url           https://en.wikipedia.org/wiki/Ali_Masykur_Musa
# country                                            Indonesia
# revid                                           1063399683.0
# Name: 3063, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1063399683": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.05365476932093101,
#               "C": 0.1401158403740908,
#               "FA": 0.0035521889397297462,
#               "GA": 0.006296684941520611,
#               "Start": 0.7368797416704508,
#               "Stub": 0.05950077475327704
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                           3064
# name                                        Hasyim Muzadi
# url           https://en.wikipedia.org/wiki/Hasyim_Muzadi
# country                                         Indonesia
# revid                                        1072922132.0
# Name: 3064, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1072922132": {
#         "wp10": {
#           "score": {
#             "prediction": "GA",
#             "probability": {
#               "B": 0.13132164492809037,
#               "C": 0.14333963588840706,
#               "FA": 0.020200287888391896,
#               "GA": 0.6809961943420475,
#               "Start": 0.020428466337368844,
#               "Stub": 0.0037137706156944185
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: GA
# Unnamed: 0                                               3065
# name                                        Abi Kusno Nachran
# url           https://en.wikipedia.org/wiki/Abi_Kusno_Nachran
# country                                             Indonesia
# revid                                            1063403183.0
# Name: 3065, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1063403183": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.023574765859213864,
#               "C": 0.024820277397906793,
#               "FA": 0.003256583755773213,
#               "GA": 0.005802783000575585,
#               "Start": 0.7516345160582549,
#               "Stub": 0.19091107392827555
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                                 3066
# name                                  Rustam Effendy Nainggolan
# url           https://en.wikipedia.org/wiki/Rustam_Effendy_N...
# country                                               Indonesia
# revid                                              1049059147.0
# Name: 3066, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1049059147": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.025543921079783632,
#               "C": 0.041407162205517045,
#               "FA": 0.003756917511955845,
#               "GA": 0.006860551446136286,
#               "Start": 0.6321234221682577,
#               "Stub": 0.29030802558834967
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                            3067
# name                                        Muhammad Nazar
# url           https://en.wikipedia.org/wiki/Muhammad_Nazar
# country                                          Indonesia
# revid                                          992150436.0
# Name: 3067, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "992150436": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.00998536767838906,
#               "C": 0.012487996314988627,
#               "FA": 0.0018275856656331895,
#               "GA": 0.0034208935931019217,
#               "Start": 0.08159542931009879,
#               "Stub": 0.8906827274377883
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                     3068
# name                                        Ngitung
# url           https://en.wikipedia.org/wiki/Ngitung
# country                                   Indonesia
# revid                                   901722698.0
# Name: 3068, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "901722698": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.008266661297157791,
#               "C": 0.0121556139905553,
#               "FA": 0.0017455084455823245,
#               "GA": 0.004008383819160513,
#               "Start": 0.04097539482277398,
#               "Stub": 0.9328484376247701
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                         3069
# name                                        Ramses Ohee
# url           https://en.wikipedia.org/wiki/Ramses_Ohee
# country                                       Indonesia
# revid                                      1096782591.0
# Name: 3069, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1096782591": {
#         "wp10": {
#           "score": {
#             "prediction": "GA",
#             "probability": {
#               "B": 0.1530522955062252,
#               "C": 0.30348912103145925,
#               "FA": 0.010860701833048938,
#               "GA": 0.470565420298395,
#               "Start": 0.05569028312981383,
#               "Stub": 0.006342178201057734
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: GA
# Unnamed: 0                                                3070
# name                                        Panusunan Pasaribu
# url           https://en.wikipedia.org/wiki/Panusunan_Pasaribu
# country                                              Indonesia
# revid                                             1107533136.0
# Name: 3070, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1107533136": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.05381862295762798,
#               "C": 0.19930557673187144,
#               "FA": 0.005914096197038062,
#               "GA": 0.019956284922832232,
#               "Start": 0.5883157480148077,
#               "Stub": 0.1326896711758225
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start
# Unnamed: 0                                                 3071
# name                                        Julian Aldrin Pasha
# url           https://en.wikipedia.org/wiki/Julian_Aldrin_Pasha
# country                                               Indonesia
# revid                                              1025723291.0
# Name: 3071, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1025723291": {
#         "wp10": {
#           "score": {
#             "prediction": "Stub",
#             "probability": {
#               "B": 0.006523377346864733,
#               "C": 0.010856362460945672,
#               "FA": 0.0013594430090618703,
#               "GA": 0.0030212291191281217,
#               "Start": 0.02852684789527355,
#               "Stub": 0.949712740168726
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Stub
# Unnamed: 0                                               3072
# name                                        Poedjono Pranyoto
# url           https://en.wikipedia.org/wiki/Poedjono_Pranyoto
# country                                             Indonesia
# revid                                            1101575086.0
# Name: 3072, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1101575086": {
#         "wp10": {
#           "score": {
#             "prediction": "GA",
#             "probability": {
#               "B": 0.22546112259136525,
#               "C": 0.2532424888856505,
#               "FA": 0.012604777233181156,
#               "GA": 0.46308166575171167,
#               "Start": 0.03999250415426393,
#               "Stub": 0.005617441383827698
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: GA
# Unnamed: 0                                     3073
# name                                        Prijono
# url           https://en.wikipedia.org/wiki/Prijono
# country                                   Indonesia
# revid                                  1085683318.0
# Name: 3073, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1085683318": {
#         "wp10": {
#           "score": {
#             "prediction": "C",
#             "probability": {
#               "B": 0.3084628514986628,
#               "C": 0.465618006452559,
#               "FA": 0.007690133245992259,
#               "GA": 0.042626013927055686,
#               "Start": 0.16327162201537126,
#               "Stub": 0.012331372860358913
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: C
# Unnamed: 0                                                 3074
# name                                      Anthony Winza Probowo
# url           https://en.wikipedia.org/wiki/Anthony_Winza_Pr...
# country                                               Indonesia
# revid                                              1104560182.0
# Name: 3074, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1104560182": {
#         "wp10": {
#           "score": {
#             "prediction": "C",
#             "probability": {
#               "B": 0.16020173529136025,
#               "C": 0.4787229655382103,
#               "FA": 0.007422244806360132,
#               "GA": 0.045895954820124936,
#               "Start": 0.29816580174708385,
#               "Stub": 0.00959129779686068
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: C
# Unnamed: 0                                                 3075
# name                                        I Gusti Ketut Pudja
# url           https://en.wikipedia.org/wiki/I_Gusti_Ketut_Pudja
# country                                               Indonesia
# revid                                              1108931157.0
# Name: 3075, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1108931157": {
#         "wp10": {
#           "score": {
#             "prediction": "GA",
#             "probability": {
#               "B": 0.21807918560877362,
#               "C": 0.15856464987600644,
#               "FA": 0.05702628060067625,
#               "GA": 0.5309780993898366,
#               "Start": 0.02904499792302607,
#               "Stub": 0.0063067866016808015
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: GA
# Unnamed: 0                                                 3076
# name                                      Tedjo Edhy Purdijatno
# url           https://en.wikipedia.org/wiki/Tedjo_Edhy_Purdi...
# country                                               Indonesia
# revid                                              1113174460.0
# Name: 3076, dtype: object
# {
#   "enwiki": {
#     "models": {
#       "wp10": {
#         "version": "0.9.2"
#       }
#     },
#     "scores": {
#       "1113174460": {
#         "wp10": {
#           "score": {
#             "prediction": "Start",
#             "probability": {
#               "B": 0.20510636087421844,
#               "C": 0.30141789005466385,
#               "FA": 0.006706137318311172,
#               "GA": 0.019278862251200894,
#               "Start": 0.4346780590776677,
#               "Stub": 0.032812690423938
#             }
#           }
#         }
#       }
#     }
#   }
# }
# RATING: Start

# %%
df_rat = pd.read_csv('data/politicans_by_country_rating.csv')
# Out:
#       Unnamed: 0.1  Unnamed: 0                   name  \
# 0                0           0        Shahjahan Noori
# 1                1           1  Abdul Ghafar Lakanwal
# 2                2           2         Majah Ha Adrif
# 3                3           3      Haroon al-Afghani
# 4                4           4            Tayyab Agha
# ...            ...         ...                    ...
# 7573          7579        7579        Rekayi Tangwena
# 7574          7580        7580       Josiah Tongogara
# 7575          7581        7581      Langton Towungana
# 7576          7582        7582    Herbert Ushewokunze
# 7577          7583        7583           Denis Walker
#
#                                                     url      country  \
# 0         https://en.wikipedia.org/wiki/Shahjahan_Noori  Afghanistan
# 1     https://en.wikipedia.org/wiki/Abdul_Ghafar_Lak...  Afghanistan
# 2          https://en.wikipedia.org/wiki/Majah_Ha_Adrif  Afghanistan
# 3       https://en.wikipedia.org/wiki/Haroon_al-Afghani  Afghanistan
# 4             https://en.wikipedia.org/wiki/Tayyab_Agha  Afghanistan
# ...                                                 ...          ...
# 7573      https://en.wikipedia.org/wiki/Rekayi_Tangwena     Zimbabwe
# 7574     https://en.wikipedia.org/wiki/Josiah_Tongogara     Zimbabwe
# 7575    https://en.wikipedia.org/wiki/Langton_Towungana     Zimbabwe
# 7576  https://en.wikipedia.org/wiki/Herbert_Ushewokunze     Zimbabwe
# 7577         https://en.wikipedia.org/wiki/Denis_Walker     Zimbabwe
#
#              revid rating
# 0     1.099689e+09     GA
# 1     9.435623e+08  Start
# 2     8.524041e+08  Start
# 3     1.095102e+09      B
# 4     1.104998e+09  Start
# ...            ...    ...
# 7573  1.073819e+09   Stub
# 7574  1.106932e+09      C
# 7575  9.042468e+08   Stub
# 7576  9.591118e+08   Stub
# 7577  1.111258e+09      C
#
# [7578 rows x 7 columns]

# %%
# Combine the population and politician datasets for analysis

df_pop = pd.read_csv("data/population_by_country.csv")

# Countries missing from the rating data set
df_combined = pd.merge(
    df_rat[['name', 'country', 'revid', 'rating']],
    df_pop[['country', 'region', 'population']], 
    how='right', on='country')

print("Countries not represented in the ratings dataset")
print(df_combined[df_combined['name'].isna()]['country'])

# Note: Only the country, "Korean", is dropped in the inner join. It represents politicians before Korea split into North Korea and South Korea
df_combined = pd.merge(
    df_rat[['name', 'country', 'revid', 'rating']],
    df_pop[['country', 'region', 'population']], 
    how='inner', on='country')

df_combined.to_csv("data/combined.csv")
# Out:
# Countries not represented in the ratings dataset
# 227            Western Sahara
# 1023                Mauritius
# 1024                  Mayotte
# 1034                  Reunion
# 1652    Sao Tome and Principe
# 1664                 eSwatini
# 1771                   Canada
# 1772            United States
# 2055                  Curacao
# 2097               Guadeloupe
# 2148               Martinique
# 2149              Puerto Rico
# 2528            French Guiana
# 4191                   Brunei
# 4529              Philippines
# 4607    China,  Hong Kong SAR
# 4608        China,  Macao SAR
# 4945                  Ireland
# 5115           United Kingdom
# 7441                Australia
# 7469         French Polynesia
# 7470                     Guam
# 7471                 Kiribati
# 7483            New Caledonia
# 7484              New Zealand
# Name: country, dtype: object

# %% [markdown]
# ### Analysis
# Top 10 countries by coverage: The 10 countries with the highest total articles per capita (in descending order) .
# Geographic regions by high quality coverage: Rank ordered list of geographic regions (in descending order) by high quality articles per capita.

# %% [markdown]
# The following articles are associated with countries with less than 100,000 people. Since minimum granularity of the population data is 100k, these countries appear to have a population of zero 0.1-millions, i.e. 0. They are excluded from this alaysis.

# %%
print(df_combined[df_combined['population'] == 0]['country'].unique())

df_combined = df_combined[df_combined['population'] > 0]
# Out:
# ['Liechtenstein' 'Monaco' 'Nauru' 'Palau' 'San Marino' 'Tuvalu']

# %%
def arts_per_cap(df_sub):
    df_sub['arts_per_cap'] = df_sub['country'].count() / df_sub['population']
    return df_sub

#df_combined.groupby(['country'], as_index=False).apply(arts_per_cap)

df_pc = df_combined.groupby(['country'], as_index=False).apply(arts_per_cap)

print("Top 10 countries with highest total artices per capita (descending), per 1 million people")
df_pc.groupby('country')['arts_per_cap'].first().sort_values(ascending=False).head(10)
# Out:
# Top 10 countries with highest total artices per capita (descending:)
# country
# Antigua and Barbuda               170.000000
# Federated States of Micronesia    130.000000
# Andorra                           100.000000
# Barbados                           93.333333
# Marshall Islands                   90.000000
# Montenegro                         60.000000
# Seychelles                         60.000000
# Luxembourg                         52.857143
# Bhutan                             51.250000
# Grenada                            50.000000
# Name: arts_per_cap, dtype: float64

# %% [markdown]
# Bottom 10 countries by coverage: The 10 countries with the lowest total articles per capita (in ascending order) .

# %%
print("Top 10 countries with lowest total artices per capita (ascending), per 1 million people")
df_pc.groupby('country')['arts_per_cap'].first().sort_values().head(10)
# Out:
# Top 10 countries with highest total artices per capita (descending:)
# country
# China           0.001392
# Mexico          0.007843
# Saudi Arabia    0.081744
# Romania         0.105263
# India           0.125600
# Sri Lanka       0.133929
# Egypt           0.135266
# Ethiopia        0.202593
# Taiwan          0.215517
# Vietnam         0.271630
# Name: arts_per_cap, dtype: float64

# %% [markdown]
# Top 10 countries by high quality: The 10 countries with the highest high quality articles per capita (in descending order).
#
# We consider the quality of any article with a rating "GA" or "FA" to be high. We assign a numerical 1 to these articles. All other are assigned 0. The numerical value is used to compute the mean article quality of a country.

# %%
df_combined['high_quality'] = df_combined.apply(lambda r: 1 if r['rating'] == "GA" or r['rating'] == "FA" else 0, axis=1)

def qual_per_cap(df_sub):
    df_sub['qual_per_cap'] = df_sub['high_quality'].mean() / df_sub['population']
    return df_sub

df_qual_pc = df_combined.groupby(['country'], as_index=False).apply(qual_per_cap)

print("Top 10 countries with highest high qualtiy articles per capita (descending), per 1 million people")
df_qual_pc.groupby('country')['qual_per_cap'].first().sort_values(ascending=False).head(10)
# Out:
# Top 10 countries with highest high qualtiy articles per capita (descending), per 1 million people
# country
# Andorra                     2.000000
# Gabon                       0.138889
# Montenegro                  0.138889
# Suriname                    0.072464
# Romania                     0.052632
# Estonia                     0.028490
# Bosnia-Herzegovina          0.028281
# Central African Republic    0.027473
# Albania                     0.025818
# Panama                      0.025253
# Name: qual_per_cap, dtype: float64

# %% [markdown]
# Bottom 10 countries by high quality: The 10 countries with the lowest high quality articles per capita (in ascending order).
#
# There were many countires that lacked a high-quality article, meaning there is a tie for the bottom 10. They are listed below.

# %%
print("Top 10 countries with lowest low qualtiy articles per capita (ascending), per 1 million people")
l = df_qual_pc.groupby('country')['qual_per_cap'].first().sort_values()
l[l == 0].index
# Out:
# Top 10 countries with lowest low qualtiy articles per capita (ascending), per 1 million people
# Index(['Zimbabwe', 'Israel', 'Iceland', 'Honduras', 'Saint Lucia', 'Guyana',
#        'Guinea-Bissau', 'Samoa', 'Seychelles', 'Grenada', 'Greece', 'Ghana',
#        'Sierra Leone', 'Gambia', 'Singapore', 'Finland', 'Mozambique',
#        'Federated States of Micronesia', 'Solomon Islands', 'Eritrea', 'Italy',
#        'Jamaica', 'Qatar', 'Paraguay', 'Namibia', 'Mongolia', 'Moldova',
#        'Mexico', 'Nicaragua', 'Marshall Islands', 'Malta', 'Niger', 'Maldives',
#        'Equatorial Guinea', 'Malawi', 'Luxembourg', 'North Macedonia',
#        'Liberia', 'Lesotho', 'Oman', 'Latvia', 'Laos', 'Zambia', 'Kuwait',
#        'Madagascar', 'Egypt', 'Fiji', 'Tonga', 'Angola', 'Timor-Leste', 'Togo',
#        'Sri Lanka', 'Brazil', 'Antigua and Barbuda', 'Argentina', 'Botswana',
#        'Trinidad and Tobago', 'Turkey', 'Bhutan', 'Turkmenistan', 'Belize',
#        'Uzbekistan', 'Barbados', 'Bangladesh', 'Bahrain', 'Bahamas', 'Vanuatu',
#        'Austria', 'Tanzania', 'Venezuela', 'Tajikistan', 'Cape Verde',
#        'Taiwan', 'Congo, Dem. Rep.', 'Cyprus', 'Algeria', 'Congo',
#        'Cote d'Ivoire', 'Comoros', 'China', 'Denmark', 'Chad', 'Djibouti',
#        'Dominica', 'St. Kitts-Nevis', 'St. Vincent and the Grenadines'],
#       dtype='object', name='country')

# %% [markdown]
# Geographic regions by total coverage: A rank ordered list of geographic regions (in descending order) by total articles per capita.

# %%
print("Top 10 regions with highest number of articles per capita (descending), per 1 million people")
df_pc.groupby('region')['arts_per_cap'].first().sort_values(ascending=False).head(10)
# Out:
# Top 10 regions with highest high qualtiy articles per capita (descending), per 1 million people
# region
# CARIBBEAN          170.000000
# OCEANIA            130.000000
# SOUTHERN EUROPE     29.642857
# WESTERN ASIA        15.333333
# WESTERN EUROPE       9.555556
# CENTRAL AMERICA      7.500000
# EASTERN EUROPE       4.239130
# SOUTHERN AFRICA      4.230769
# SOUTH ASIA           2.871046
# CENTRAL ASIA         2.239583
# Name: arts_per_cap, dtype: float64

# %%
print("Top 10 regions with highest high qualtiy articles per capita (descending), per 1 million people")
df_qual_pc.groupby('region')['qual_per_cap'].first().sort_values(ascending=False).head(10)
# Out:
# Top 10 regions with highest high qualtiy articles per capita (descending), per 1 million people
# region
# SOUTHERN EUROPE    0.025818
# WESTERN ASIA       0.007246
# EASTERN AFRICA     0.006460
# WESTERN AFRICA     0.004390
# EASTERN EUROPE     0.002787
# CENTRAL ASIA       0.002422
# SOUTHEAST ASIA     0.001751
# SOUTH ASIA         0.001237
# CARIBBEAN          0.000000
# SOUTHERN AFRICA    0.000000
# Name: qual_per_cap, dtype: float64
